# %%
import json
import csv
import pandas as pd

# %%
df = pd.read_csv('../../data/schemapile/processed/schemapile.csv')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 22989 entries, 0 to 22988
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   schema_name  22989 non-null  str
#  1   url          22989 non-null  str
#  2   license      22989 non-null  str
#  3   permissive   22989 non-null  bool
# dtypes: bool(1), str(3)
# memory usage: 561.4 KB

# %%
df.describe()
# Out:
#                                schema_name  \
# count                                22989
# unique                               22989
# top     692793_2021-09-21-08-02.backup.sql
# freq                                     1
#
#                                                       url license permissive
# count                                               22989   22989      22989
# unique                                              22989      21          1
# top     https://github.com/alaindet/garnet/blob/7d26a5...     MIT       True
# freq                                                    1   14673      22989

# %%
df["permissive"].value_counts()
# Out:
# permissive
# True    22989
# Name: count, dtype: int64

# %%
df["license"].value_counts()
# Out:
# license
# MIT                   14673
# APACHE-2.0             6488
# BSD-3-CLAUSE            970
# UNLICENSE               268
# CC0-1.0                 183
# BSD-2-CLAUSE            114
# ECL-2.0                  98
# ISC                      78
# ARTISTIC-2.0             48
# WTFPL                    20
# CC-BY-4.0                14
# ZLIB                      9
# BSL-1.0                   8
# UPL-1.0                   5
# 0BSD                      4
# POSTGRESQL                2
# BSD-3-CLAUSE-CLEAR        2
# NCSA                      2
# MS-PL                     1
# MIT-0                     1
# BSD-4-CLAUSE              1
# Name: count, dtype: int64
